# %%
import pandas as pd
import random
import numpy as np
from termcolor import colored

# %% [markdown]
# # Preparación de los datos

# %%
data_benigna = pd.read_csv('./DATA/ALEXA_BENIGNOS/TIME/Benigno_Alexa.csv')
data_benigna.head()
# Out:
#             Name  Netflows First_Protocol Second_Protocol Third_Protocol  \
# 0  0-csves/0.csv        42            TCP             UDP            NaN
# 1  0-csves/1.csv        46            UDP             TCP          ICMP6
# 2  1-csves/0.csv       187            TCP             UDP            NaN
# 3  1-csves/1.csv       125            TCP             UDP            NaN
# 4  2-csves/0.csv        34            TCP             UDP            NaN
#
#        p1_d      p2_d       p3_d  duration    max_d  ...  first_dp  second_dp  \
# 0  138.6785  193.6895  194.93300  6778.668  240.226  ...       443       80.0
# 1    0.0000    0.1090   45.09775   784.026   93.159  ...        53       80.0
# 2    0.1055    1.9840  120.20850  8454.095  210.496  ...       443       80.0
# 3    0.0000    1.2800    4.41400   395.649   15.013  ...       443       53.0
# 4    0.0000    0.2210   37.53275   469.353   52.661  ...       443       53.0
#
# ...

# %%
print(colored(f"El conjunto de datos benigno no aleatorio inicial tiene {data_benigna.shape[0]} registros y {data_benigna.shape[1]} características", attrs=['bold']))
# Out:
# El conjunto de datos benigno no aleatorio inicial tiene 2501 registros y 31 características

# %%
data_bitcash = pd.read_csv('./DATA/BITCASH/TIME/BITCASH.csv')
data_bitcash.head()
# Out:
#             Name  Netflows First_Protocol  Second_Protocol  Third_Protocol  \
# 0  0-csves/0.csv         2            TCP              NaN             NaN
# 1  1-csves/0.csv         2            TCP              NaN             NaN
# 2  1-csves/1.csv         2            TCP              NaN             NaN
# 3  1-csves/2.csv         2            TCP              NaN             NaN
# 4  1-csves/3.csv         2            TCP              NaN             NaN
#
#         p1_d      p2_d       p3_d  duration    max_d  ...  first_dp  \
# 0    0.29150    0.3090    0.32650     0.618    0.344  ...      3337
# 1  293.50750  293.5080  293.50850   587.016  293.509  ...      3337
# 2  243.19225  243.1935  243.19475   486.387  243.196  ...      3337
# 3  264.13100  264.1320  264.13300   528.264  264.134  ...      3337
# 4  243.56325  243.5635  243.56375   487.127  243.564  ...      3337
#
#    second_dp  third_dp  p1_ip  p2_ip  p3_ip    p1_ib   p2_ib    p3_ib  Type
# ...

# %%
print(colored(f"El conjunto de datos de bitcash tiene {data_bitcash.shape[0]} registros y {data_bitcash.shape[1]} características", attrs=['bold']))
# Out:
# El conjunto de datos de bitcash tiene 485 registros y 31 características

# %%
data_bitcoin = pd.read_csv('./DATA/BITCOIN/TIME/BITCOIN.csv')
data_bitcoin.head()
# Out:
#             Name  Netflows First_Protocol  Second_Protocol  Third_Protocol  \
# 0  0-csves/0.csv         2            TCP              NaN             NaN
# 1  0-csves/1.csv         6            TCP              NaN             NaN
# 2  0-csves/2.csv         2            TCP              NaN             NaN
# 3  0-csves/3.csv         4            TCP              NaN             NaN
# 4  0-csves/4.csv         2            TCP              NaN             NaN
#
#         p1_d      p2_d       p3_d  duration    max_d  ...  first_dp  \
# 0  245.09100  245.0910  245.09100   490.182  245.091  ...      3332
# 1  122.82400  240.5955  242.30000  1134.032  242.868  ...      3332
# 2  242.47425  242.4745  242.47475   484.949  242.475  ...      3332
# 3  241.01000  241.9955  242.99850   968.052  243.051  ...      3332
# 4    0.12325    0.1235    0.12375     0.247    0.124  ...      3332
#
#    second_dp  third_dp  p1_ip  p2_ip  p3_ip    p1_ib   p2_ib     p3_ib  Type
# ...

# %%
print(colored(f"El conjunto de datos de bitcoin tiene {data_bitcoin.shape[0]} registros y {data_bitcoin.shape[1]} características", attrs=['bold']))
# Out:
# El conjunto de datos de bitcoin tiene 247 registros y 31 características

# %%
data_litecoin = pd.read_csv('./DATA/LITECOIN/TIME/LITECOIN.csv')
data_litecoin.head()
# Out:
#             Name  Netflows First_Protocol  Second_Protocol  Third_Protocol  \
# 0  0-csves/0.csv         2            TCP              NaN             NaN
# 1  0-csves/1.csv         2            TCP              NaN             NaN
# 2  0-csves/2.csv         4            TCP              NaN             NaN
# 3  0-csves/3.csv         2            TCP              NaN             NaN
# 4  0-csves/4.csv         2            TCP              NaN             NaN
#
#         p1_d      p2_d       p3_d  duration    max_d  ...  first_dp  \
# 0  274.53550  274.5360  274.53650   549.072  274.537  ...      3333
# 1  285.28225  285.2885  285.29475   570.577  285.301  ...      3333
# 2   14.59825  118.0000  221.40300   472.005  221.412  ...      3333
# 3  584.41425  584.4285  584.44275  1168.857  584.457  ...      3333
# 4  325.51925  325.5375  325.55575   651.075  325.574  ...      3333
#
#    second_dp  third_dp  p1_ip  p2_ip  p3_ip    p1_ib    p2_ib     p3_ib  Type
# ...

# %%
print(colored(f"El conjunto de datos de litecoin tiene {data_litecoin.shape[0]} registros y {data_litecoin.shape[1]} características", attrs=['bold']))
# Out:
# El conjunto de datos de litecoin tiene 349 registros y 31 características

# %%
data_eth = pd.read_csv('./DATA/ETHERUM/TIME/ETHERUM.csv')
data_eth.head()
# Out:
#             Name  Netflows First_Protocol  Second_Protocol  Third_Protocol  \
# 0  0-csves/0.csv         2            TCP              NaN             NaN
# 1  1-csves/1.csv         2            TCP              NaN             NaN
# 2  1-csves/2.csv        12            TCP              NaN             NaN
# 3  1-csves/3.csv         4            TCP              NaN             NaN
# 4  1-csves/4.csv         7            TCP              NaN             NaN
#
#         p1_d      p2_d       p3_d  duration    max_d  ...  first_dp  \
# 0   65.96125   66.6435   67.32575   133.287   68.008  ...     56525
# 1  300.02900  300.0320  300.03500   600.064  300.038  ...     56731
# 2   28.79975   56.7100   73.71975   704.725  113.899  ...     56731
# 3   20.03200   25.0070   29.98525   100.041   30.016  ...     56731
# 4    5.68250    6.5630   40.75300   174.606   75.137  ...     56731
#
#    second_dp  third_dp   p1_ip  p2_ip   p3_ip     p1_ib    p2_ib     p3_ib  \
# ...

# %%
print(colored(f"El conjunto de datos de ethereum tiene {data_eth.shape[0]} registros y {data_eth.shape[1]} características", attrs=['bold']))
# Out:
# El conjunto de datos de ethereum tiene 959 registros y 31 características

# %%
data_monero = pd.read_csv('./DATA/MONERO/TIME/MONERO.csv')
data_monero.head()
# Out:
#             Name  Netflows First_Protocol  Second_Protocol  Third_Protocol  \
# 0  0-csves/0.csv         2            TCP              NaN             NaN
# 1  0-csves/3.csv         2            TCP              NaN             NaN
# 2  0-csves/4.csv         8            TCP              NaN             NaN
# 3  1-csves/0.csv         2            TCP              NaN             NaN
# 4  1-csves/2.csv         2            TCP              NaN             NaN
#
#         p1_d      p2_d       p3_d  duration    max_d  ...  first_dp  \
# 0  269.96800  269.9680  269.96800   539.936  269.968  ...     51085
# 1  497.44000  497.4400  497.44000   994.880  497.440  ...     51085
# 2    0.06950    0.0795   73.29725   586.342  293.003  ...     14444
# 3  526.38700  526.3870  526.38700  1052.774  526.387  ...     53473
# 4  275.21225  275.2125  275.21275   550.425  275.213  ...     53473
#
#    second_dp  third_dp  p1_ip  p2_ip  p3_ip    p1_ib   p2_ib    p3_ib  Type
# ...

# %%
print(colored(f"El conjunto de datos de monero tiene {data_monero.shape[0]} registros y {data_monero.shape[1]} características", attrs=['bold']))
# Out:
# El conjunto de datos de monero tiene 192 registros y 31 características

# %%
data_mineros_no_identificada = pd.read_csv('./DATA/SIN_CLASIFICAR/TIME/Minero_sin_clasificar.csv')
data_mineros_no_identificada.head()
# Out:
#             Name  Netflows First_Protocol Second_Protocol Third_Protocol  \
# 0  0-csves/0.csv      1564            TCP             UDP           ICMP
# 1  0-csves/1.csv     50572            TCP             UDP            NaN
# 2  1-csves/0.csv         2            TCP             NaN            NaN
# 3  1-csves/1.csv        20            TCP             UDP            NaN
# 4  2-csves/0.csv       322            TCP             UDP            NaN
#
#      p1_d      p2_d       p3_d   duration    max_d  ...  first_dp  second_dp  \
# 0    0.00    0.1010    1.72100  10701.930  177.706  ...        53      443.0
# 1    0.12    0.1210    0.12400  11602.090   55.906  ...        53      443.0
# 2  366.69  366.7300  366.77000    733.460  366.810  ...       443    49270.0
# 3    0.00    4.1530    7.70100     86.786   12.255  ...       443       53.0
# 4    0.00    1.9585   27.59625   6541.874  303.171  ...       443     5355.0
#
# ...

# %%
print(colored(f"El conjunto de datos de mineros sin identificar tiene {data_mineros_no_identificada.shape[0]} registros y {data_mineros_no_identificada.shape[1]} características", attrs=['bold']))
# Out:
# El conjunto de datos de mineros sin identificar tiene 37053 registros y 31 características

# %% [markdown]
# # Estructuración de los datos de Ventanas de tiempo

# %% [markdown]
# Agrego una nueva característica a los conjuntos de datos con registros mineros denominada 'cryptocurrency', la cual me permite saber que tipo de criptomoneda pertenece al proceso de minería. Al conjunto de datos benigno también se le agrego esta columna para poder concatenar todos los registros.

# %%
data_benigna['Cryptocurrency'] = 'Does not have'
data_bitcoin['Cryptocurrency'] = 'Bitcoin'
data_bitcash['Cryptocurrency'] = 'Bitcash'
data_litecoin['Cryptocurrency'] = 'Litecoin'
data_eth['Cryptocurrency'] = 'Etherium'
data_monero['Cryptocurrency'] = 'Monero'
data_mineros_no_identificada['Cryptocurrency'] = 'Unidentified'

# %% [markdown]
# ### Concatenación de datos mineros identificados y datos benignos

# %%
pure_data_miner_time = pd.concat([data_bitcoin,data_bitcash,data_litecoin,data_eth,data_monero,data_benigna], axis=0)
pure_data_miner_time.head()
# Out:
#             Name  Netflows First_Protocol Second_Protocol Third_Protocol  \
# 0  0-csves/0.csv         2            TCP             NaN            NaN
# 1  0-csves/1.csv         6            TCP             NaN            NaN
# 2  0-csves/2.csv         2            TCP             NaN            NaN
# 3  0-csves/3.csv         4            TCP             NaN            NaN
# 4  0-csves/4.csv         2            TCP             NaN            NaN
#
#         p1_d      p2_d       p3_d  duration    max_d  ...  second_dp  \
# 0  245.09100  245.0910  245.09100   490.182  245.091  ...    51453.0
# 1  122.82400  240.5955  242.30000  1134.032  242.868  ...    51469.0
# 2  242.47425  242.4745  242.47475   484.949  242.475  ...    51455.0
# 3  241.01000  241.9955  242.99850   968.052  243.051  ...    51435.0
# 4    0.12325    0.1235    0.12375     0.247    0.124  ...    51431.0
#
#    third_dp  p1_ip  p2_ip  p3_ip    p1_ib   p2_ib     p3_ib  Type  \
# ...

# %%
print(colored(f'Hago un proceso de resetear los indices del dataframe, para que no apunte un mismo indice a varios registros.', attrs=['bold']))
pure_data_miner_time = pure_data_miner_time.reset_index()
# Out:
# Hago un proceso de resetear los indices del dataframe, para que no apunte un mismo indice a varios registros.

# %%
print(colored(f'Genero un rango de valores', attrs=['bold']))
indices = list(pure_data_miner_time.index)
print(colored(f'El rango de valores se le aplicó aleatoriedad de manera pseudoaleatoria', attrs=['bold']))
random.shuffle(indices)
# Out:
# Genero un rango de valores
# El rango de valores se le aplicó aleatoriedad de manera pseudoaleatoria

# %%
print(colored(f'Ordeno los registros del conjunto con los indices aleatorios', attrs=['bold']))
pure_data_miner_time = pure_data_miner_time.reindex(indices)
pure_data_miner_time
# Out:
# Ordeno los registros del conjunto con los indices aleatorios
#       index              Name  Netflows First_Protocol Second_Protocol  \
# 4401   2169  1113-csves/1.csv       400            TCP             UDP
# 2650    418   214-csves/1.csv        46            UDP             NaN
# 3525   1293   664-csves/1.csv       189            TCP             UDP
# 176     176    29-csves/1.csv         5            TCP             NaN
# 4403   2171  1114-csves/1.csv        52            TCP             UDP
# 1409    328   11-csves/42.csv        12            TCP             NaN
# 4544   2312  1186-csves/0.csv       130            TCP             UDP
# 3059    827   426-csves/0.csv       149            TCP             UDP
# 2614    382   196-csves/0.csv       174            TCP             UDP
# 1398    317   11-csves/26.csv        14            TCP             NaN
# 4443   2211  1134-csves/1.csv       900            TCP             UDP
# ...

# %%
print(colored(f'Guardo el conjunto de datos', attrs=['bold']))
pure_data_miner_time.to_csv('data_identificada.csv', index=False)
# Out:
# Guardo el conjunto de datos

# %% [markdown]
# ## Concatenación de datos mineros no identificados y datos benignos

# %%
not_pure_data_miner_time = pd.concat([data_mineros_no_identificada,data_benigna], axis=0)
not_pure_data_miner_time
# Out:
#                   Name  Netflows First_Protocol Second_Protocol  \
# 0        0-csves/0.csv      1564            TCP             UDP
# 1        0-csves/1.csv     50572            TCP             UDP
# 2        1-csves/0.csv         2            TCP             NaN
# 3        1-csves/1.csv        20            TCP             UDP
# 4        2-csves/0.csv       322            TCP             UDP
# 5        2-csves/2.csv       152            UDP             TCP
# 6        3-csves/0.csv        12            UDP             NaN
# 7        3-csves/1.csv       332            UDP             TCP
# 8        4-csves/1.csv        32            TCP             NaN
# 9        5-csves/0.csv         2            TCP             NaN
# 10       5-csves/1.csv        23            TCP             UDP
# 11       6-csves/0.csv         6            TCP             NaN
# 12       6-csves/1.csv        16            TCP             UDP
# 13       7-csves/0.csv        10            TCP             UDP
# ...

# %%
print(colored(f'Hago un proceso de resetear los indices del dataframe, para que no apunte un mismo indice a varios registros.', attrs=['bold']))
not_pure_data_miner_time = not_pure_data_miner_time.reset_index()
# Out:
# Hago un proceso de resetear los indices del dataframe, para que no apunte un mismo indice a varios registros.

# %%
print(colored(f'Genero un rango de valores', attrs=['bold']))
indices = list(not_pure_data_miner_time.index)
print(colored(f'El rango de valores se le aplicó aleatoriedad de manera pseudoaleatoria', attrs=['bold']))
random.shuffle(indices)
# Out:
# Genero un rango de valores
# El rango de valores se le aplicó aleatoriedad de manera pseudoaleatoria

# %%
print(colored(f'Ordeno los registros del conjunto con los indices aleatorios', attrs=['bold']))
not_pure_data_miner_time = not_pure_data_miner_time.reindex(indices)
not_pure_data_miner_time.head()
# Out:
# Ordeno los registros del conjunto con los indices aleatorios
#        index               Name  Netflows First_Protocol Second_Protocol  \
# 36016  36016  20-csves/8177.csv        17            UDP           ICMP6
# 12659  12659  18-csves/5102.csv        28          ICMP6            ICMP
# 8388    8388   18-csves/831.csv        18          ICMP6            ICMP
# 16127  16127  18-csves/8570.csv        28          ICMP6            ICMP
# 23859  23859  19-csves/6208.csv        30          ICMP6            ICMP
#
#       Third_Protocol  p1_d   p2_d     p3_d  duration  ...  second_dp  \
# 36016            NaN   0.0  3.001  360.024  2790.015  ...     1900.0
# 12659            UDP   0.0  0.000    0.000    13.505  ...     1281.0
# 8388             UDP   0.0  0.000    0.000   556.202  ...     1281.0
# 16127            TCP   0.0  0.000    0.000  1021.895  ...     1281.0
# 23859            UDP   0.0  0.000    0.000  1080.234  ...     1281.0
#
# ...

# %%
print(colored(f'Guardo el conjunto de datos', attrs=['bold']))
not_pure_data_miner_time.to_csv('data_no_identificada.csv',index=False)
# Out:
# Guardo el conjunto de datos
