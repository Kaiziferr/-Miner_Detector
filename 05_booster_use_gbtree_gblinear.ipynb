# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaiziferr/-Miner_Detector/blob/master/05_booster_use_gbtree_gblinear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

from sklearn.datasets import (
    make_classification,
    make_friedman1,
    make_regression)

from sklearn.model_selection import (
    GridSearchCV,
    train_test_split)

from sklearn.metrics import (
    make_scorer,
    recall_score,
    f1_score
)

from xgboost import XGBClassifier, XGBRegressor

# %% [markdown]
# # **Info**
#
# ---
#
#
# @By: Steven Bernal
#
# @Nickname: Kaiziferr
#
# @Git: https://github.com/Kaiziferr

# %% [markdown]
# # **Functions**
# ---

# %%
def split_test_train(

    X:pd.DataFrame,
    y:pd.Series,
    **kward)->tuple:
  """Randomly split the data into training and validation sets."""
  X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    **kward
  )
  return X_train, X_test, y_train, y_test

# %% [markdown]
# # **Config**
# ---

# %%
random_seed=73

# %% [markdown]
# # **Data**
# ---

# %% [markdown]
# The purpose of this notebook is to visualize the behavior of the hyperparameter booster: gbtree and gblinear, for fictitious datasets of classification and regression. For classification, the classes are unbalanced; and for regression, the data can be linear or nonlinear.

# %% [markdown]
# ## **Config Metric**

# %%
scoring_clasification = make_scorer(
    f1_score,
    labels = [0,1,2,3,4],
    average='micro'

)

# %% [markdown]
# The parameter dictionary is defined with:
#
# - n_estimators: number of trees
# - learning_rate: learning rate
# - booster: type of booste

# %%
dict_params = {
    "n_estimators": [100, 300, 600, 900],
    "learning_rate": [0.01, 0.05, 0.1, 0.2],
    "booster": ["gbtree", "gblinear"]
}

# %% [markdown]
# ## **Clasification**
# ---

# %% [markdown]
# A synthetic dataset is generated, consisting of five classes, with 1500 records, and 5% misclassified. It has 8 informative features and two redundant ones. The classes are unbalanced

# %%
X, y = make_classification(
    n_samples = 1500,
    n_features = 10,
    n_informative = 8,
    n_redundant = 2,
    n_classes = 5,
    flip_y = 0.05,
    weights = [0.25, 0.15, 0.30, 0.20, 0.10],
    random_state = random_seed
)

# %% [markdown]
# Randomly split the data into training and validation sets.

# %%
X_train, X_test, y_train, y_test = split_test_train(X, y, **{
    "test_size": 0.25,
    "shuffle": True,
    "stratify": y,
    "random_state": random_seed
})

# %% [markdown]
# The model is instantiated.

# %%
model = XGBClassifier(
    random_state = random_seed
)

# %% [markdown]
# The 'GridSearchCV' is defined with 5-fold cross-validation and a modified F1 metric.

# %%
grid = GridSearchCV(
    model,
    dict_params,
    refit=True,
    scoring=scoring_clasification,
    cv=5,
    return_train_score=True,
    verbose = 0
)

# %% [markdown]
# The model is fitted

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=73, ...),
#              param_grid={'booster': ['gbtree', 'gblinear'],
#                          'learning_rate': [0.01, 0.05, 0.1, 0.2],
#                          'n_estimators': [100, 300, 600, 900]},
#              return_train_score=True,
#              scoring=make_scorer(f1_score, response_method='predict', labels=[0, 1, 2, 3, 4], average=micro))

# %%
resultados = pd.DataFrame(grid.cv_results_)
resultados.filter(regex = '(param.*|mean_t|std_t)')\
    .drop(columns = 'params')\
    .sort_values('mean_test_score', ascending = False).head()
# Out:
#    param_booster  param_learning_rate  param_n_estimators  mean_test_score  \
# 12        gbtree                  0.2                 100         0.728000
# 10        gbtree                  0.1                 600         0.722667
# 9         gbtree                  0.1                 300         0.721778
# 14        gbtree                  0.2                 600         0.720000
# 13        gbtree                  0.2                 300         0.720000
#
#     std_test_score  mean_train_score  std_train_score
# 12        0.036585               1.0              0.0
# 10        0.045724               1.0              0.0
# 9         0.039313               1.0              0.0
# 14        0.038848               1.0              0.0
# 13        0.036325               1.0              0.0

# %%
print("-----------------------------------")
print("Best hyperparameters found")
print("-----------------------------------")
print(f"{grid.best_params_} : {grid.best_score_} ({grid.scoring})")
# Out:
# -----------------------------------
# Best hyperparameters found
# -----------------------------------
# {'booster': 'gbtree', 'learning_rate': 0.2, 'n_estimators': 100} : 0.728 (make_scorer(f1_score, response_method='predict', labels=[0, 1, 2, 3, 4], average=micro))

# %% [markdown]
# For the classification problem, it is observed that the booster that works best is 'gbtree with an F1 score of

# %%
grid.best_score_
# Out:
# 0.728

# %% [markdown]
# # **Regression**
# ---

# %% [markdown]
# **No Lineal**

# %% [markdown]
# Synthetic data is generated for a regression problem with a non-linear relationship. The number of records is 1500, with 10 features and a noise level of 3 (standard deviation).

# %%
X, y = make_friedman1(
    n_samples = 1500,
    n_features = 10,
    noise=3,
    random_state = random_seed
)

# %% [markdown]
# Randomly split the data into training and validation sets.

# %%
X_train, X_test, y_train, y_test = split_test_train(X, y, **{
    "test_size": 0.25,
    "random_state": random_seed
})

# %% [markdown]
# The model is instantiated.

# %%
model = XGBRegressor(
    random_state = random_seed
)

# %% [markdown]
# The 'GridSearchCV' is defined with 5-fold cross-validation and a neg_mean_absolute_error metric.

# %%
grid = GridSearchCV(
    model,
    dict_params,
    refit=True,
    scoring="neg_mean_absolute_error",
    cv=5,
    return_train_score=True,
    verbose = 0
)

# %% [markdown]
# The model is fitted

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=73, ...),
#              param_grid={'booster': ['gbtree', 'gblinear'],
#                          'learning_rate': [0.01, 0.05, 0.1, 0.2],
#                          'n_estimators': [100, 300, 600, 900]},
#              return_train_score=True, scoring='neg_mean_absolute_error')

# %%
resultados = pd.DataFrame(grid.cv_results_)
resultados.filter(regex = '(param.*|mean_t|std_t)')\
    .drop(columns = 'params')\
    .sort_values('mean_test_score', ascending = False).head()
# Out:
#   param_booster  param_learning_rate  param_n_estimators  mean_test_score  \
# 5        gbtree                 0.05                 300        -2.771670
# 2        gbtree                 0.01                 600        -2.776635
# 4        gbtree                 0.05                 100        -2.776953
# 3        gbtree                 0.01                 900        -2.779367
# 8        gbtree                 0.10                 100        -2.779665
#
#    std_test_score  mean_train_score  std_train_score
# 5        0.160466         -0.345594         0.043617
# 2        0.166085         -0.846360         0.037368
# 4        0.137588         -0.933703         0.036628
# 3        0.181602         -0.634394         0.045391
# 8        0.167668         -0.537783         0.046150

# %%
print("-----------------------------------")
print("Best hyperparameters found")
print("-----------------------------------")
print(f"{grid.best_params_} : {grid.best_score_} ({grid.scoring})")
# Out:
# -----------------------------------
# Best hyperparameters found
# -----------------------------------
# {'booster': 'gbtree', 'learning_rate': 0.05, 'n_estimators': 300} : -2.7716704377998003 (neg_mean_absolute_error)

# %% [markdown]
# For the classification problem, it is observed that the booster that works best is 'gbtree with an neg_mean_absolute_error score of

# %%
-1*grid.best_score_
# Out:
# 2.7716704377998003

# %% [markdown]
# **Lineal**

# %% [markdown]
# Generate synthetic data for a linear regression problem. This dataset will consist of 1,500 records, with 10 features where 8 are informative, and with 10% noise. There will be a single target.

# %%
X, y = make_regression(
    n_samples = 1500,
    n_features = 10,
    n_informative = 8,
    n_targets = 1,
    bias = 0.2,
    tail_strength = 0.3,
    noise = 0.1,
    random_state = random_seed
)

# %% [markdown]
# Randomly split the data into training and validation sets.

# %%
X_train, X_test, y_train, y_test = split_test_train(X, y, **{
    "test_size": 0.25,
    "random_state": random_seed
})

# %% [markdown]
# The 'GridSearchCV' is defined with 5-fold cross-validation and a neg_mean_absolute_error metric.

# %%
grid = GridSearchCV(
    model,
    dict_params,
    refit=True,
    scoring="neg_mean_absolute_error",
    cv=5,
    return_train_score=True,
    verbose = 0
)

# %% [markdown]
# The model is fitted

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=73, ...),
#              param_grid={'booster': ['gbtree', 'gblinear'],
#                          'learning_rate': [0.01, 0.05, 0.1, 0.2],
#                          'n_estimators': [100, 300, 600, 900]},
#              return_train_score=True, scoring='neg_mean_absolute_error')

# %% [markdown]
# For the classification problem, it is observed that the booster that works best is 'gblinear with an neg_mean_absolute_error score of

# %%
resultados = pd.DataFrame(grid.cv_results_)
resultados.filter(regex = '(param.*|mean_t|std_t)')\
    .drop(columns = 'params')\
    .sort_values('mean_test_score', ascending = False).head()
# Out:
#    param_booster  param_learning_rate  param_n_estimators  mean_test_score  \
# 23      gblinear                 0.05                 900        -0.076779
# 22      gblinear                 0.05                 600        -0.076779
# 29      gblinear                 0.20                 300        -0.076779
# 30      gblinear                 0.20                 600        -0.076779
# 31      gblinear                 0.20                 900        -0.076779
#
#     std_test_score  mean_train_score  std_train_score
# 23        0.003088         -0.075858         0.000765
# 22        0.003088         -0.075858         0.000765
# 29        0.003087         -0.075856         0.000764
# 30        0.003087         -0.075856         0.000764
# 31        0.003087         -0.075856         0.000764

# %%
-1*grid.best_score_
# Out:
# 0.0767785912184936
