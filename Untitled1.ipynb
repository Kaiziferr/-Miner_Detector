# %%
import pandas as pd

# %%
data = pd.read_csv('./moderna_procesada.txt')

# %%
len(data)
# Out:
# 1066256

# %%
data.head()
# Out:
#                            Top
# 0        https://www.apple.com
# 1      https://www.youtube.com
# 2       https://www.google.com
# 3      https://www.blogger.com
# 4  https://www.docs.google.com

# %%
len(data[data.duplicated()])
# Out:
# 25909

# %%
data = data.drop_duplicates("Top")

# %%
len(data)
# Out:
# 1040347

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Top]
# Index: []

# %%
lista = data["Top"].values.tolist()
lista
# Out:
# ['https://www.apple.com',
#  'https://www.youtube.com',
#  'https://www.google.com',
#  'https://www.blogger.com',
#  'https://www.docs.google.com',
#  'https://www.support.google.com',
#  'https://www.play.google.com',
#  'https://www.microsoft.com',
#  'https://www.cloudflare.com',
#  'https://www.en.wikipedia.org',
#  'https://www.wordpress.org',
#  'https://www.linkedin.com',
#  'https://www.adobe.com',
#  'https://www.maps.google.com',
#  'https://www.plus.google.com',
#  'https://www.googleusercontent.com',
#  'https://www.europa.eu',
#  'https://www.vimeo.com',
#  'https://www.mozilla.org',
#  'https://www.accounts.google.com',
#  'https://www.youtu.be',
#  'https://www.drive.google.com',
#  'https://www.sites.google.com',
#  'https://www.medium.com',
#  'https://www.istockphoto.com',
#  'https://www.bp.blogspot.com',
#  'https://www.bbc.co.uk',
#  'https://www.facebook.com',
#  'https://www.vk.com',
#  'https://www.creativecommons.org',
#  'https://www.line.me',
# ...

# %%
len(lista)
# Out:
# 1040347

# %%
for i in lista:
    file = open("moderna_procesada_2.txt","a")
    file.write(i+"\n")
    file.close()
